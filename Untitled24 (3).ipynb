# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('C://Users//asus//Downloads//breast cancer.csv',encoding = "ISO-8859-1")
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.drop(columns=['id'], inplace = True)
data.drop(columns=['Unnamed: 32'], inplace = True)

# %%
def plot_correlation_map(data):

    corr = data.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .7 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 5 }

        )
plot_correlation_map( data )

# %%
data.drop(columns=['texture_worst'], inplace = True)
data.drop(columns=['perimeter_worst'], inplace = True)
data.drop(columns=['area_worst'], inplace = True)
data.drop(columns=['smoothness_worst'], inplace = True)
data.drop(columns=['compactness_worst'], inplace = True)
data.drop(columns=['concavity_worst'], inplace = True)
data.drop(columns=['concave points_worst'], inplace = True)
data.drop(columns=['symmetry_worst'], inplace = True)
data.drop(columns=['fractal_dimension_worst'], inplace = True)
data.drop(columns=['texture_se'], inplace = True)
data.drop(columns=['perimeter_se'], inplace = True)
data.drop(columns=['area_se'], inplace = True)
data.drop(columns=['smoothness_se'], inplace = True)
data.drop(columns=['compactness_se'], inplace = True)
data.drop(columns=['concavity_se'], inplace = True)
data.drop(columns=['concave points_se'], inplace = True)
data.drop(columns=['symmetry_se'], inplace = True)
data.drop(columns=['fractal_dimension_se'], inplace = True)
data.drop(columns=['radius_worst'], inplace = True)
data.drop(columns=['texture_mean'], inplace = True)
data.drop(columns=['smoothness_mean'], inplace = True)
data.drop(columns=['compactness_mean'], inplace = True)
data.drop(columns=['concavity_mean'], inplace = True)
data.drop(columns=['concave points_mean'], inplace = True)
data.drop(columns=['symmetry_mean'], inplace = True)
data.drop(columns=['fractal_dimension_mean'], inplace = True)
data.drop(columns=['radius_se'], inplace = True)

# %%
data
# Out:
#     diagnosis  radius_mean  perimeter_mean  area_mean
# 0           M        17.99          122.80     1001.0
# 1           M        20.57          132.90     1326.0
# 2           M        19.69          130.00     1203.0
# 3           M        11.42           77.58      386.1
# 4           M        20.29          135.10     1297.0
# ..        ...          ...             ...        ...
# 564         M        21.56          142.00     1479.0
# 565         M        20.13          131.20     1261.0
# 566         M        16.60          108.30      858.1
# 567         M        20.60          140.10     1265.0
# 568         B         7.76           47.92      181.0
#
# [569 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.title("disease type")
plt.xlabel("diagnosis")
plt.ylabel("disease type count")
vc=data['diagnosis'].value_counts()
vc.plot.bar(rot=45)

# %%
def plot_correlation_map(data):

    corr = data.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .7 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 20 }

        )
plot_correlation_map( data )

# %%
from sklearn import datasets
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier 
from sklearn import metrics  
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %%
x=data[["radius_mean","perimeter_mean","area_mean"]]
y=data["diagnosis"]
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.3)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
knn=KNeighborsClassifier(n_neighbors=20)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
print("Accuracy=",accuracy_score(y_pred,y_test))
# Out:
# Accuracy= 0.9122807017543859
